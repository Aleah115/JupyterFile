# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 新三板

# %%
#导入数据
path = 'C:/Users/84678/Desktop/做市商效率/新三板做市交易企业.xlsx'
df_b_c = pd.read_excel(path, sheet_name="基础层竞价")
df_b_m = pd.read_excel(path, sheet_name="基础层做市")
df_i_c = pd.read_excel(path, sheet_name="创新层竞价")
df_i_m = pd.read_excel(path, sheet_name="创新层做市")

# %%
# name_list = ["b_c", "b_m", "i_c", "i_m"]
df_list = [df_b_c, df_b_m, df_i_c, df_i_m]

# %%
#删去第一行
for f in df_list:
    f.drop(0,inplace = True)

# %%
df_b_m2014 = df_b_m[df_b_m['匹配期'] == "2014.12.31"]
df_b_m2015 = df_b_m[df_b_m['匹配期'] == "2015.12.31"]
df_i_m2014 = df_i_m[df_i_m['匹配期'] == "2014.12.31"]
df_i_m2015 = df_i_m[df_i_m['匹配期'] == "2015.12.31"]

# %%
bins = 5

# %%
for f in ['df_b_m2014','df_b_m2015','df_i_m2014','df_i_m2015']:
    # df.cat.codes把各类型用整数编码代替
    f['Segment_a'] = bins - pd.qcut(f['总资产'], bins).cat.codes
    f['Segment_s'] = bins - pd.qcut(f['流通股合计'], bins).cat.codes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [61], in <cell line: 1>()
#       1 for f in ['df_b_m2014','df_b_m2015','df_i_m2014','df_i_m2015']:
#       2     # df.cat.codes把各类型用整数编码代替
# ----> 3     f['Segment_a'] = bins - pd.qcut(f['总资产'], bins).cat.codes
#       4     f['Segment_s'] = bins - pd.qcut(f['流通股合计'], bins).cat.codes
#
# TypeError: string indices must be integers

# %%
divi = pd.merge(df_list[1], df_list[0], on=['Segment_a','Segment_s'], how="outer")
divi.dropna(how="any", inplace=True)

# %% [markdown]
# # 保持现有模型，再加入PSM

# %% [markdown]
# ## 新三板基础层

# %% [markdown]
# ### 设立处理组和对照组

# %%
def get_diff_df(df_left, df_right):
    
    divi = pd.merge(df_left, df_right, on=['Segment_a', 'Segment_s'], how='outer')
    divi.dropna(how = 'any', inplace = True)
    divi.reset_index(inplace = True)
    divi = divi.drop('index', axis = 1)
    divi['diff_a'] = abs(divi['总资产_y'] - divi['总资产_x'])
    divi['diff_s'] = abs(divi['流通三板股_y'] - divi['流通三板股_x'])
    divi['diff'] = divi['diff_a'] + divi['diff_s']
    
    return divi

# %%
df_divi = get_diff_df(df_list[1], df_list[0])

# %%
# groupby的数据结构可以这样调用：(直接运行下就看到了)
print("按照代码x排列的第0家公司的代码名称：",list(df_divi_g)[0][0])
print("按照代码x排列的第0家公司所对应的数据表格：\n")
list(df_divi_g)[0][1]
# Out:
# 按照代码x排列的第0家公司的代码名称： 430054.NQ
# 按照代码x排列的第0家公司所对应的数据表格：
#           代码_x  名称_x         总资产_x     流通三板股_x  Segment_a  Segment_s  \
# 0    430054.NQ  超毅网络  2.611635e+08  62453881.0          2          2
# 1    430054.NQ  超毅网络  2.611635e+08  62453881.0          2          2
# 2    430054.NQ  超毅网络  2.611635e+08  62453881.0          2          2
# 3    430054.NQ  超毅网络  2.611635e+08  62453881.0          2          2
# 4    430054.NQ  超毅网络  2.611635e+08  62453881.0          2          2
# ..         ...   ...           ...         ...        ...        ...
# 280  430054.NQ  超毅网络  2.611635e+08  62453881.0          2          2
# 281  430054.NQ  超毅网络  2.611635e+08  62453881.0          2          2
# 282  430054.NQ  超毅网络  2.611635e+08  62453881.0          2          2
# 283  430054.NQ  超毅网络  2.611635e+08  62453881.0          2          2
# 284  430054.NQ  超毅网络  2.611635e+08  62453881.0          2          2
#
#           代码_y  名称_y         总资产_y     流通三板股_y        diff_a      diff_s  \
# 0    430019.NQ  新松佳和  2.254879e+08  18443206.0  3.567563e+07  44010675.0
# 1    430042.NQ   科瑞讯  1.942798e+08  28751950.0  6.688373e+07  33701931.0
# 2    430068.NQ  纬纶环保  2.315586e+08  19502500.0  2.960488e+07  42951381.0
# 3    430191.NQ  波尔通信  1.458005e+08  24705308.0  1.153630e+08  37748573.0
# 4    430241.NQ  威林科技  1.634726e+08  24026475.0  9.769095e+07  38427406.0
# ..         ...   ...           ...         ...           ...         ...
# 280  873808.NQ  永超新材  2.229744e+08  19933750.0  3.818912e+07  42520131.0
# 281  873823.NQ  尚洋科技  2.003023e+08  29376392.0  6.086127e+07  33077489.0
# 282  873825.NQ   梦天门  1.781419e+08  32716706.0  8.302161e+07  29737175.0
# 283  873836.NQ  鸿星科技  1.712422e+08  19987392.0  8.992128e+07  42466489.0
# 284  873874.NQ  涅生科技  1.585893e+08  19293000.0  1.025742e+08  43160881.0
#
#              diff
# 0    7.968630e+07
# 1    1.005857e+08
# 2    7.255627e+07
# 3    1.531116e+08
# 4    1.361184e+08
# ..            ...
# 280  8.070925e+07
# 281  9.393876e+07
# 282  1.127588e+08
# 283  1.323878e+08
# 284  1.457351e+08
#
# [285 rows x 13 columns]

# %%
list(df_divi.groupby(['代码_x']))[0][1]
# Out:
#           代码_x  名称_x         总资产_x     流通三板股_x  Segment_a  Segment_s  \
# 0    430054.NQ  超毅网络  2.611635e+08  62453881.0          2          2
# 1    430054.NQ  超毅网络  2.611635e+08  62453881.0          2          2
# 2    430054.NQ  超毅网络  2.611635e+08  62453881.0          2          2
# 3    430054.NQ  超毅网络  2.611635e+08  62453881.0          2          2
# 4    430054.NQ  超毅网络  2.611635e+08  62453881.0          2          2
# ..         ...   ...           ...         ...        ...        ...
# 280  430054.NQ  超毅网络  2.611635e+08  62453881.0          2          2
# 281  430054.NQ  超毅网络  2.611635e+08  62453881.0          2          2
# 282  430054.NQ  超毅网络  2.611635e+08  62453881.0          2          2
# 283  430054.NQ  超毅网络  2.611635e+08  62453881.0          2          2
# 284  430054.NQ  超毅网络  2.611635e+08  62453881.0          2          2
#
#           代码_y  名称_y         总资产_y     流通三板股_y        diff_a      diff_s  \
# 0    430019.NQ  新松佳和  2.254879e+08  18443206.0  3.567563e+07  44010675.0
# 1    430042.NQ   科瑞讯  1.942798e+08  28751950.0  6.688373e+07  33701931.0
# 2    430068.NQ  纬纶环保  2.315586e+08  19502500.0  2.960488e+07  42951381.0
# 3    430191.NQ  波尔通信  1.458005e+08  24705308.0  1.153630e+08  37748573.0
# 4    430241.NQ  威林科技  1.634726e+08  24026475.0  9.769095e+07  38427406.0
# ..         ...   ...           ...         ...           ...         ...
# 280  873808.NQ  永超新材  2.229744e+08  19933750.0  3.818912e+07  42520131.0
# 281  873823.NQ  尚洋科技  2.003023e+08  29376392.0  6.086127e+07  33077489.0
# 282  873825.NQ   梦天门  1.781419e+08  32716706.0  8.302161e+07  29737175.0
# 283  873836.NQ  鸿星科技  1.712422e+08  19987392.0  8.992128e+07  42466489.0
# 284  873874.NQ  涅生科技  1.585893e+08  19293000.0  1.025742e+08  43160881.0
#
#              diff
# 0    7.968630e+07
# 1    1.005857e+08
# 2    7.255627e+07
# 3    1.531116e+08
# 4    1.361184e+08
# ..            ...
# 280  8.070925e+07
# 281  9.393876e+07
# 282  1.127588e+08
# 283  1.323878e+08
# 284  1.457351e+08
#
# [285 rows x 13 columns]

# %%
temp = df_divi.groupby(['代码_x'])['diff'].idxmin().to_frame()
df_con = df_divi.iloc[temp.iloc[:,0]]

# %%
# 输出表
df_con.to_excel('C:/Users/84678/Desktop/做市商效率/基础层公司对照公司.xlsx')

# %% [markdown]
# # 科创板
# 科创板总资产数据是2022中报数据，流通股合计是2022.6.30数据

# %%
#导入数据
path = 'C:/Users/84678/Desktop/做市商效率/科创板做市交易.xlsx'
df_tech_c = pd.read_excel(path, sheet_name="科创板竞价")
df_tech_m = pd.read_excel(path, sheet_name="科创板做市")

# %%
df_tech_list = [df_tech_c, df_tech_m]

# %%
df_tech_c
# Out:
#             代码    名称                 总资产                流通股合计
# 0         Code  Name         wgsd_assets  share_totaltradable
# 1    688001.SH  华兴源创       5347519808.29           50401792.0
# 2    688003.SH  天准科技       2746542490.87             74403000
# 3    688004.SH  博汇科技        759269049.31             39843320
# 4    688005.SH  容百科技  22567432172.950001            275810300
# ..         ...   ...                 ...                  ...
# 387  688787.SH  海天瑞声        842436074.15              9095000
# 388  688788.SH  科思科技       2921954740.53             64841076
# 389  688793.SH   倍轻松        878561062.71             13098500
# 390  688798.SH  艾为电子       4930815615.58             33440000
# 391  688799.SH  华纳药厂       1834841176.07             19975000
#
# [392 rows x 4 columns]

# %%
#删去总资产和流通三板股有空值的数据_new
for f in df_tech_list:
    f.dropna(how = 'any', inplace = True)
    f.drop(0,inplace = True)
    f.reset_index(inplace=True)
    f[['总资产','流通股合计']] = f[['总资产','流通股合计']].apply(pd.to_numeric)
    del f['index']

# %%
df_tech_m
# Out:
#             代码       名称                 做市首日           总资产         流通股合计
# 0    688002.SH     睿创微纳  2022-10-31 00:00:00  5.606617e+09  2.571523e+08
# 1    688006.SH     杭可科技  2022-10-31 00:00:00  6.656095e+09  1.139562e+08
# 2    688009.SH     中国通号  2022-10-31 00:00:00  1.127219e+11  3.985393e+09
# 3    688012.SH     中微公司  2022-10-31 00:00:00  1.822547e+10  3.288530e+08
# 4    688017.SH     绿的谐波  2022-12-05 00:00:00  2.136693e+09  9.190998e+07
# ..         ...      ...                  ...           ...           ...
# 105  688789.SH     宏华数科  2022-12-05 00:00:00  1.869960e+09  1.615000e+07
# 106  688800.SH      瑞可达  2022-10-31 00:00:00  1.978623e+09  2.295000e+07
# 107  688819.SH     天能股份  2022-10-31 00:00:00  3.016841e+10  1.285071e+08
# 108  688981.SH     中芯国际  2022-10-31 00:00:00  4.047572e+10  7.834511e+09
# 109  689009.SH  九号公司-WD  2023-02-13 00:00:00  8.988434e+09  5.088841e+07
#
# [110 rows x 5 columns]

# %%
bins = 5
for f in df_tech_list:
    # df.cat.codes把各类型用整数编码代替
    f['Segment_a'] = bins - pd.qcut(f['总资产'], bins).cat.codes
    f['Segment_s'] = bins - pd.qcut(f['流通股合计'], bins).cat.codes

# %%
divi_tech = pd.merge(df_tech_list[1], df_tech_list[0], on=['Segment_a','Segment_s'], how="outer")
divi_tech.dropna(how="any", inplace=True)

# %%
def get_diff_tech_df(df_left, df_right):
    
    divi = pd.merge(df_left, df_right, on=['Segment_a', 'Segment_s'], how='outer')
    divi.dropna(how = 'any', inplace = True)
    divi.reset_index(inplace = True)
    divi = divi.drop('index', axis = 1)
    divi['diff_a'] = abs(divi['总资产_y'] - divi['总资产_x'])
    divi['diff_s'] = abs(divi['流通股合计_y'] - divi['流通股合计_x'])
    divi['diff'] = divi['diff_a'] + divi['diff_s']
    
    return divi

# %%
df_tech_divi = get_diff_tech_df(df_tech_list[1], df_tech_list[0])

# %%
list(df_tech_divi.groupby(['代码_x']))[0][1]
# Out:
#          代码_x  名称_x                 做市首日         总资产_x      流通股合计_x  \
# 0   688002.SH  睿创微纳  2022-10-31 00:00:00  5.606617e+09  257152320.0
# 1   688002.SH  睿创微纳  2022-10-31 00:00:00  5.606617e+09  257152320.0
# 2   688002.SH  睿创微纳  2022-10-31 00:00:00  5.606617e+09  257152320.0
# 3   688002.SH  睿创微纳  2022-10-31 00:00:00  5.606617e+09  257152320.0
# 4   688002.SH  睿创微纳  2022-10-31 00:00:00  5.606617e+09  257152320.0
# 5   688002.SH  睿创微纳  2022-10-31 00:00:00  5.606617e+09  257152320.0
# 6   688002.SH  睿创微纳  2022-10-31 00:00:00  5.606617e+09  257152320.0
# 7   688002.SH  睿创微纳  2022-10-31 00:00:00  5.606617e+09  257152320.0
# 8   688002.SH  睿创微纳  2022-10-31 00:00:00  5.606617e+09  257152320.0
# 9   688002.SH  睿创微纳  2022-10-31 00:00:00  5.606617e+09  257152320.0
# 10  688002.SH  睿创微纳  2022-10-31 00:00:00  5.606617e+09  257152320.0
# 11  688002.SH  睿创微纳  2022-10-31 00:00:00  5.606617e+09  257152320.0
# 12  688002.SH  睿创微纳  2022-10-31 00:00:00  5.606617e+09  257152320.0
# 13  688002.SH  睿创微纳  2022-10-31 00:00:00  5.606617e+09  257152320.0
#
#     Segment_a  Segment_s       代码_y  名称_y         总资产_y     流通股合计_y  \
# 0           2          2  688003.SH  天准科技  2.746542e+09  74403000.0
# 1           2          2  688010.SH  福光股份  2.560355e+09  95987743.0
# 2           2          2  688050.SH  爱博医疗  2.174629e+09  68464490.0
# 3           2          2  688136.SH  科兴制药  3.060700e+09  64935291.0
# 4           2          2  688181.SH  八亿时空  2.241219e+09  76815962.0
# 5           2          2  688182.SH  灿勤科技  2.229706e+09  70000000.0
# 6           2          2  688238.SH  和元生物  2.540590e+09  69007994.0
# 7           2          2  688248.SH  南网科技  3.197055e+09  76710824.0
# 8           2          2  688285.SH  高铁电气  3.031092e+09  75280000.0
# 9           2          2  688308.SH   欧科亿  2.104462e+09  64620800.0
# 10          2          2  688560.SH  明冠新材  2.283499e+09  88266636.0
# 11          2          2  688598.SH  金博股份  3.279264e+09  65104238.0
# 12          2          2  688697.SH  纽威数控  2.979327e+09  69416695.0
# 13          2          2  688788.SH  科思科技  2.921955e+09  64841076.0
#
#           diff_a       diff_s          diff
# 0   2.860075e+09  182749320.0  3.042824e+09
# 1   3.046263e+09  161164577.0  3.207427e+09
# 2   3.431988e+09  188687830.0  3.620676e+09
# 3   2.545917e+09  192217029.0  2.738134e+09
# 4   3.365398e+09  180336358.0  3.545735e+09
# 5   3.376911e+09  187152320.0  3.564063e+09
# 6   3.066027e+09  188144326.0  3.254172e+09
# 7   2.409562e+09  180441496.0  2.590004e+09
# 8   2.575525e+09  181872320.0  2.757397e+09
# 9   3.502156e+09  192531520.0  3.694687e+09
# 10  3.323118e+09  168885684.0  3.492004e+09
# 11  2.327354e+09  192048082.0  2.519402e+09
# 12  2.627290e+09  187735625.0  2.815026e+09
# 13  2.684663e+09  192311244.0  2.876974e+09

# %%
#为每个做市企业找出对应的差值最小的对照企业
temp_tech_x = df_tech_divi.groupby(['代码_x'])['diff'].idxmin().to_frame()
temp_tech = df_tech_divi.iloc[temp_tech_x.iloc[:,0]]

# %%
#一个对照企业只保留其差值最小的做市企业，其余删去
temp_tech_y = temp_tech.groupby(['代码_y'])['diff'].idxmin().to_frame()
df_tech_con = df_tech_divi.iloc[temp_tech_y.iloc[:,0]]

# %%
df_tech_con
# Out:
#            代码_x    名称_x                 做市首日         总资产_x       流通股合计_x  \
# 222   688126.SH  沪硅产业-U  2022-12-05 00:00:00  2.273069e+10  1.346260e+09
# 458   688777.SH    中控技术  2022-10-31 00:00:00  1.105965e+10  2.693721e+08
# 839   688067.SH    爱威科技  2022-12-05 00:00:00  5.479104e+08  4.016714e+07
# 758   688029.SH    南微医学  2022-12-05 00:00:00  3.582634e+09  6.216101e+07
# 592   688350.SH    富淼科技  2023-02-14 00:00:00  1.818135e+09  6.118419e+07
# 98    688232.SH    新点软件  2022-12-20 00:00:00  6.129040e+09  7.035204e+07
# 1285  688161.SH    威高骨科  2022-10-31 00:00:00  5.753044e+09  4.975766e+07
# 958   688183.SH    生益电子  2023-02-03 00:00:00  6.541764e+09  3.033481e+08
# 667   688019.SH    安集科技  2022-12-05 00:00:00  1.799398e+09  4.292435e+07
